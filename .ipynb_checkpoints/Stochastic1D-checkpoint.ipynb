# %% [markdown]
# Stochastic 1D
# =====
# ***

# %% [markdown]
# A one-dimensional stochastic model for the dipole field $x(t)$. The field is generated by a series of impulsive (delta function) events. The event time follows a Poisson process and the event amplitude has a uniform distribution $U(a,b)$.  A small number of negative (destructive) events are permitted by adopting a negative lower limit (a<0), but the average amplitude must be position to sustain the field against diffusive losses. The variance of the dipole moment depends on the range $b-a$. A white noise source with mean 0 and variance $q$ is added to the equation for $x(t)$.

# %%
using Plots
using Distributions
using StatsBase
using DelimitedFiles

# %% [markdown]
# Draw event times from an exponential distribution

# %%
myr = 1.0e6;
recurrence = 3030/myr;         # average recurrence time (Myr)
nevents = 100;
tevent = rand(Exponential(recurrence),nevents);  # Poisson event times

# plot distribution of event times
println("mean recurrence time = ",mean(tevent)," Myr")
histogram(tevent,label="event times",xlabel="event time (Myr)",ylabel="Number")
# Out:
# mean recurrence time = 0.002701832177093357 Myr

# %% [markdown]
# Specify and sample distribution of event amplitudes

# %%
Amax = 0.455
Amin = -0.13
amp_p = rand(Uniform(Amin,Amax),nevents)

# include random (white) noise
np = rand(Normal(),2*nevents); #called wi in paper
qp = 45;       #  gaussian noise variance

# set level of quenching
x0 = 5.0;

# %%
# Compute spike times
spike_times = cumsum(tevent)

# Plot as spikes
plot(spike_times, amp_p, seriestype = :stem,
     xlabel = "Time (Myr)", ylabel = "Amplitude",
    xlim=(0,0.05),
     title = "Event amplitudes Aᵢ", legend = false)

# %% [markdown]
# Integrate equations for dipole field. Each event interval $\Delta t$ is divided into two parts. Diffusion causes the dipole to decrease during $\Delta t/2$. Diffusion and a single source event contribute to $x(t)$ over second half of the event interval. Gaussian noise is added at each half time step.

# %%
x0 = 5.0;
# allocate memory for solution
x = zeros(2*nevents);
t = zeros(2*nevents);


# decay rate for dipole (gamma = 1/tau)
gamma = 0.025 * 1000;    # convert to Myr

# initial condition
t[1] = 0.0;
x[1] = 5.0;
j = 2;

# integrate of number of events
for i = j : nevents
    
    # magnetic diffusion over half time step dt
    dt = tevent[i]/2.0;
    t[j] = t[j-1] + dt;
    gp = exp(-x[j-1]^2/1.8^2);  # x-dependence of gaussian noise
    x[j] = x[j-1] * exp(-gamma * dt) + np[j]*sqrt(gp*qp*dt);;
    
    # magnetic diffusion over remaining time step
    j += 1;
    t[j] = t[j-1] + dt;
    x[j] = x[j-1] * exp(-gamma * dt)
    
    # evaluate quenching
    fp = 1.0/ (1.0 + (x[j]/x0)^2);
    gp = exp(-x[j]^2/1.8^2);
    
    # add event and random noise
    x[j] += amp_p[i] * x[j] * fp + np[j]*sqrt(gp*qp*dt); 
    j+= 1;
    
end
t[end] = t[end-1]
x[end] = x[end-1]
println("mean x = ",mean(abs.(x))," std x = ",std(abs.(x)))
# Out:
# mean x = 5.943440251859638 std x = 0.7814115142355542

# %%
Amax = 0.84
Amin = -0.45
amp_p = rand(Uniform(Amin,Amax),nevents)

# include random (white) noise
np = rand(Normal(),2*nevents); #called wi in paper
qp = 45;       #  gaussian noise variance

# set level of quenching
x0 = 5.0;
# allocate memory for solution
x = zeros(2*nevents);
t = zeros(2*nevents);


# decay rate for dipole (gamma = 1/tau)
gamma = 0.025 * 1000;    # convert to Myr

# initial condition
t[1] = 0.0;
x[1] = 5.0;
j = 2;

# integrate of number of events
for i = j : nevents
    
    # magnetic diffusion over half time step dt
    dt = tevent[i]/2.0;
    t[j] = t[j-1] + dt;
    gp = exp(-x[j-1]^2/1.8^2);  # x-dependence of gaussian noise
    x[j] = x[j-1] * exp(-gamma * dt) + np[j]*sqrt(gp*qp*dt);;
    
    # magnetic diffusion over remaining time step
    j += 1;
    t[j] = t[j-1] + dt;
    x[j] = x[j-1] * exp(-gamma * dt)
    
    # evaluate quenching
    fp = 1.0/ (1.0 + (x[j]/x0)^2);
    gp = exp(-x[j]^2/1.8^2);
    
    # add event and random noise
    x[j] += amp_p[i] * x[j] * fp + np[j]*sqrt(gp*qp*dt); 
    j+= 1;
    
end
t[end] = t[end-1]
x[end] = x[end-1]
println("mean x = ",mean(abs.(x))," std x = ",std(abs.(x)))
# Out:
# mean x = 3.7977027488489643 std x = 1.6776009223835688

# %%
# print time series 
idecimate = 1;
plot(t[1:idecimate:end],(x[1:idecimate:end]),
    label="x",xlabel="time (Myr)",
    ylabel="Dipole Moment  (1.0e22 A m2)",
    xlim=(0,0.05),
    ylim=(0,15)
)

# %%
h = fit(Histogram,x,nbins=100)
plot(h,label="x(t)")

# %%
# plot time series 
idecimate = 1;
plot(t[1:idecimate:end],(x[1:idecimate:end]),
label="x",xlabel="time (Myr)",
ylabel="Dipole Moment  (1.0e22 A m2)"
)

# %%
x_mean = mean(abs.(x))
x_std = std(abs.(x))
cutoff = x_mean - x_std
# Out:
# 2.1201018264653957

# %% [markdown]
# ## Lhullier 2013 Algorithm

# %%
function analyze_x_intervals(t::AbstractVector, x::AbstractVector, cutoff::Real)
    # Identify where x is below the cutoff (in absolute value)
    below_cutoff = abs.(x) .< cutoff

    # Find start and end indices of below-cutoff regions
    transitions = diff([false; below_cutoff; false])
    starts = findall(transitions .== 1)
    ends = findall(transitions .== -1) .- 1

    if isempty(starts)
        println("No values for x below cutoff")
        mean_x = mean(abs.(x))
        std_x = std(abs.(x))
        return NaN, NaN, 1, mean_x, std_x, 999
    end
    
    # Build time intervals
    intervals = [(t[s], t[e]) for (s, e) in zip(starts, ends)]
    # Total time span
    total_time = t[end] - t[1]

    # Time spent below cutoff

    time_below_cutoff = sum(t[e] - t[s] for (s, e) in zip(starts, ends))

    proportion_below_cutoff = time_below_cutoff / total_time

    # Event classification and mask for exclusions
    event_types = String[]
    exclusion_mask = trues(length(x))  # include everything initially
    
    reversal_count = 0

    for (s, e) in zip(starts, ends)
        sign_start = sign(x[s])
        sign_end = sign(x[e])

        if sign_start != sign_end
            push!(event_types, "reversal")
            reversal_count += 1
        else
            push!(event_types, "excursion")
        end

        exclusion_mask[s:e] .= false  # exclude this interval
    end
    
    # Statistics on remaining x values
    remaining_x = x[exclusion_mask]
    if isempty(remaining_x)
        mean_x = NaN
        std_x = NaN
    else
        mean_x = mean(abs.(remaining_x))
        std_x = std(abs.(remaining_x))
    end

    # Reversal rate (number of reversals per unit time)
    reversal_rate = reversal_count / total_time

    return intervals, event_types, proportion_below_cutoff,
           mean_x, std_x, reversal_rate
end
# Out:
# analyze_x_intervals (generic function with 1 method)

# %%
intervals, event_types, prop, mean_x, std_x, rev_rate = analyze_x_intervals(t, x, cutoff)

#println("Intervals: ", intervals)
#println("Event Types: ", event_types)
#println("Proportion below cutoff: ", prop)
#println("Mean (excluding): ", mean_x)
#println("Std (excluding): ", std_x)
#println("Reversal rate: ", rev_rate, " per Myr")
# Out:
# ([(0.06084532201823545, 0.07334551481288544), (0.17435985412292995, 0.1832108062385956), (0.19474067595861913, 0.19578927329733536), (0.2061175075173589, 0.2061175075173589), (0.2364344998441849, 0.2364344998441849), (0.24322706827239696, 0.24322706827239696)], ["excursion", "excursion", "excursion", "excursion", "excursion", "excursion"], 0.08543202506645951, 4.162385155873648, 1.5161836064615732, 0.0)

# %%
for i in [1,2,3,4]
    cutoff = mean_x - std_x
    intervals, event_types, prop, mean_x, std_x, rev_rate = analyze_x_intervals(t, x, cutoff)
        #println("Intervals: ", intervals)
    #println("Event Types: ", event_types)
    #println("Proportion below cutoff: ", prop)
    println("Mean (excluding): ", mean_x)
    println("Std (excluding): ", std_x)
    println("Reversal rate: ", rev_rate, " per Myr")
end
# Out:
# Mean (excluding): 4.488487500947519
# Std (excluding): 1.4294210625587145
# Reversal rate: 0.0 per Myr
# Mean (excluding): 4.744168791414496
# Std (excluding): 1.3596009489264091
# Reversal rate: 0.0 per Myr
# Mean (excluding): 5.0584448935107345
# Std (excluding): 1.292656066626714
# Reversal rate: 0.0 per Myr
# Mean (excluding): 5.3279626650872824
# Std (excluding): 1.2237734183471043
# Reversal rate: 0.0 per Myr

# %% [markdown]
# ## Sweep

# %%
elapsed = @elapsed begin

    #recurrences = 0.002:0.01:0.010 # average recurrence time (Myr)
    recurrences = [0.006]
    Amin_vals = -1.5:0.2:1
    Amax_vals = -0.5:0.2:2
    
    # Create an empty matrix to store results with NaNs
    x_means = fill(NaN, length(recurrences), length(Amin_vals), length(Amax_vals))
    x_stds = fill(NaN, length(recurrences), length(Amin_vals), length(Amax_vals))
    rev_freqs = fill(NaN, length(recurrences), length(Amin_vals), length(Amax_vals))
    props = fill(NaN, length(recurrences), length(Amin_vals), length(Amax_vals))
    
    for (k, recurrence) in enumerate(recurrences)
    
        nevents = 5000;
        tevent = rand(Exponential(recurrence),nevents);  # Poisson event times
    
        # plot distribution of event times
        println("mean recurrence time = ",mean(tevent)," Myr")
        
        for (l, Amin) in enumerate(Amin_vals)
            for (m, Amax) in enumerate(Amax_vals)
                if Amin >= Amax 
                    #All outputs will remain NaN
                    continue
                end    
        
                amp_p = rand(Uniform(Amin,Amax),nevents);
            
                # include random (white) noise
                np = rand(Normal(),2*nevents); #called wi in paper
                qp = 100;       #  gaussian noise variance
                
                # set level of quenching
                x0 = 5.0;
            
                # allocate memory for solution
                x = zeros(2*nevents);
                t = zeros(2*nevents);
                
                
                # decay rate for dipole (gamma = 1/tau)
                gamma = 0.025 * 1000;    # convert to Myr
                
                # initial condition
                t[1] = 0.0;
                x[1] = 5.0;
                j = 2;
                
                # integrate of number of events
                for i = j : nevents
                    
                    # magnetic diffusion over half time step dt
                    dt = tevent[i]/2.0;
                    t[j] = t[j-1] + dt;
                    gp = exp(-x[j-1]^2/1.8^2);  # x-dependence of gaussian noise
                    x[j] = x[j-1] * exp(-gamma * dt) + np[j]*sqrt(gp*qp*dt);;
                    
                    # magnetic diffusion over remaining time step
                    j += 1;
                    t[j] = t[j-1] + dt;
                    x[j] = x[j-1] * exp(-gamma * dt)
                    
                    # evaluate quenching
                    fp = 1.0/ (1.0 + (x[j]/x0)^2);
                    gp = exp(-x[j]^2/1.8^2);
                    
                    # add event and random noise
                    x[j] += amp_p[i] * x[j] * fp + np[j]*sqrt(gp*qp*dt); 
                    j+= 1;
                    
                    
                end
                t[end] = t[end-1]
                x[end] = x[end-1]
                mean_x = mean(abs.(x))
                std_x = std(abs.(x))
                println("Amin = ", Amin, " Amax = " , Amax, " R = ", recurrence,  " mean x = ",mean_x," std x = ",std_x)
                x_means[k,l,m] = mean_x
                x_stds[k,l,m] = std_x
                
                #Calculate reversal rate
                cutoff = mean_x - std_x
                prev_rev_rate = Inf
                tol = 0.1 #tolerance for reversal rate change
                max_iters = 10
                
                for n in 1:max_iters
                    intervals, event_types, prop, mean_exc_x, std_exc_x, rev_rate = analyze_x_intervals(t, x, cutoff)
                    println("rev rate: ", rev_rate, " per Myr")
                    if abs(rev_rate - prev_rev_rate) < tol
                        break
                    end
                    cutoff = mean_exc_x - std_exc_x
                    prev_rev_rate = rev_rate
                end
                            rev_freqs[k,l,m] = rev_rate
                println("final rev rate: ", rev_rate, " per Myr")
                props[k,l,m] = prop
            end
        end   
    
    end
end

println("Elapsed time: $(round(elapsed, digits=3)) seconds")
# Out:
# mean recurrence time = 0.006010079518356128 Myr
# Amin = -1.5 Amax = -0.5 R = 0.006 mean x = 0.47777234682636965 std x = 0.4391681060325298
# rev rate: 1.098438363017091 per Myr
# rev rate: 3.02902700104713 per Myr
# rev rate: 5.492191815085455 per Myr
# rev rate: 8.388074772130514 per Myr
# rev rate: 10.285377399160035 per Myr
# rev rate: 11.550245817179716 per Myr
# rev rate: 12.681970191197324 per Myr
# rev rate: 13.980124620217524 per Myr
# rev rate: 15.078562983234614 per Myr
# rev rate: 16.310145390253776 per Myr
# final rev rate: 16.310145390253776 per Myr
# Amin = -1.5 Amax = -0.3 R = 0.006 mean x = 0.4931508114116956 std x = 0.4460742494732288
# rev rate: 1.2981544290201985 per Myr
# rev rate: 3.82789126505956 per Myr
# rev rate: 7.322922420113941 per Myr
# rev rate: 9.220225047143462 per Myr
# rev rate: 11.716675872182305 per Myr
# rev rate: 13.181260356205094 per Myr
# rev rate: 14.412842763224257 per Myr
# rev rate: 15.611139159242901 per Myr
# rev rate: 16.543147467257402 per Myr
# rev rate: 17.408583753270868 per Myr
# final rev rate: 17.408583753270868 per Myr
# Amin = -1.5 Amax = -0.1 R = 0.006 mean x = 0.5092975401285886 std x = 0.44967523265766396
# rev rate: 1.564442517024342 per Myr
# rev rate: 0.0 per Myr
# rev rate: 0.0 per Myr
# final rev rate: 0.0 per Myr
# Amin = 0.9 Amax = 1.5 R = 0.006 mean x = 14.85365651722344 std x = 2.660830556938885
# rev rate: 0.0 per Myr
# rev rate: 0.0 per Myr
# final rev rate: 0.0 per Myr
# Amin = 0.9 Amax = 1.7 R = 0.006 mean x = 15.568898030469354 std x = 2.7673624492432247
# rev rate: 0.0 per Myr
# rev rate: 0.0 per Myr
# final rev rate: 0.0 per Myr
# Amin = 0.9 Amax = 1.9 R = 0.006 mean x = 16.209896341216034 std x = 2.8807740397149546
# rev rate: 0.0 per Myr
# rev rate: 0.0 per Myr
# final rev rate: 0.0 per Myr
# Elapsed time: 3.9 seconds

# %%
# Create a single plot
p = contour(
    Amax_vals,
    Amin_vals,
    x_means[1, :, :],
    levels=[NaN],  # doesn't show anything
    legend=:topright,
    xlabel="Aₘₐₓ",
    ylabel="Aₘᵢₙ",
    colorbar=false
)

# Add dummy lines for the legend
plot!(p, [NaN], [NaN], linecolor=:blue, linewidth=2, label="Mean: 5.7")
plot!(p, [NaN], [NaN], linecolor=:red, linewidth=2, label="Std: 2.79")
plot!(p, [NaN], [NaN], linecolor=:green, linewidth=2, label="Freq: 4")

# Overlay all contours
for k in 1:length(recurrences)
    contour!(
        p,
        Amax_vals,
        Amin_vals,
        x_means[k, :, :],
        levels=[5.7],
        linewidth=2,
        linecolor=:blue,
        label=""
    )

    contour!(
        p,
        Amax_vals,
        Amin_vals,
        x_stds[k, :, :],
        levels=[2.79],
        linewidth=2,
        linecolor=:red,
        label=""
    )

    contour!(
        p,
        Amax_vals,
        Amin_vals,
        rev_freqs[k, :, :],
        levels=[4],
        linewidth=2,
        linecolor=:green,
        label=""
    )
end

display(p)

# %%
# Target values
target_mean = 5.7
target_std = 2.79
target_revfreq = 4.0  # reversals per Myr

# Store the errors
errors = fill(Inf, size(x_means))  # default to Inf everywhere

for k in 1:length(recurrences)
    for l in 1:length(Amin_vals)
        for m in 1:length(Amax_vals)
            model_mean = x_means[k, l, m]
            model_std = x_stds[k, l, m]
            model_revfreq = rev_freqs[k, l, m]

            # Skip models with NaN reversal frequency
            #if isnan(model_revfreq)
            #    continue
            #end

            #Skip models where reversing time >25%
            #if props[k,l,m] > 0.25
            #    continue
            #end
            errors[k, l, m] = 
                ((model_mean - target_mean) / target_mean)^2 +
                ((model_std - target_std) / target_std)^2 +
                ((model_revfreq - target_revfreq) / target_revfreq)^2
        end
    end
end

# Flatten the errors
flat_errors = vec(errors)

# Sort and find indices of top 10 smallest errors
sorted_indices = sortperm(flat_errors)
top_10_indices = sorted_indices[1:10]

println("Top 10 matches:")

for idx in top_10_indices
    best_idx = CartesianIndices(errors)[idx]
    best_k, best_l, best_m = Tuple(best_idx)

    best_recurrence = recurrences[best_k]
    best_Amin = Amin_vals[best_l]
    best_Amax = Amax_vals[best_m]

    println("\nMatch $(idx):")
    println("  Recurrence time = $(best_recurrence) Myr")
    println("  Amin = $(best_Amin)")
    println("  Amax = $(best_Amax)")
    println("  Model mean(|x|) = ", x_means[best_k, best_l, best_m])
    println("  Model std(|x|) = ", x_stds[best_k, best_l, best_m])
    println("  Model reversal frequency = ", rev_freqs[best_k, best_l, best_m], " per Myr")
    println("  Proportion reversing time = ", props[best_k, best_l, best_m])
    println("  Normalized Error = ", errors[best_k, best_l, best_m])
end
# Out:
# Top 10 matches:
#
# Match 146:
#   Recurrence time = 0.006 Myr
#   Amin = -1.1
#   Amax = 1.7
#   Model mean(|x|) = 3.9909164527573897
#   Model std(|x|) = 3.4868146711757375
#   Model reversal frequency = 3.9610353090616317 per Myr
#   Proportion reversing time = 0.22283146628475456
#   Normalized Error = 0.15237568913763697
#
# Match 133:
#   Recurrence time = 0.006 Myr
#   Amin = -1.1
#   Amax = 1.5
#   Model mean(|x|) = 2.835464710971243
#   Model std(|x|) = 2.729864845118161
#   Model reversal frequency = 3.361887111052309 per Myr
#   Proportion reversing time = 0.6025582528676982
#   Normalized Error = 0.2784703742669843
#
# Match 121:
#   Recurrence time = 0.006 Myr
#   Amin = -0.9
#   Amax = 1.3
#   Model mean(|x|) = 2.8725984512489706
#   Model std(|x|) = 2.555012924896044
#   Model reversal frequency = 1.9971606600310747 per Myr
#   Proportion reversing time = 0.6688259321156431
#   Normalized Error = 0.5038552265401046
#
# Match 122:
#   Recurrence time = 0.006 Myr
#   Amin = -0.7
#   Amax = 1.3
#   Model mean(|x|) = 4.169081834869037
#   Model std(|x|) = 3.0030561782927285
#   Model reversal frequency = 1.2981544290201985 per Myr
#   Proportion reversing time = 0.6324860468598612
#   Normalized Error = 0.5342159502605177
#
# Match 158:
#   Recurrence time = 0.006 Myr
#   Amin = -1.3
#   Amax = 1.9
#   Model mean(|x|) = 4.278564579582664
#   Model std(|x|) = 3.840477183992895
#   Model reversal frequency = 1.6310145390253776 per Myr
#   Proportion reversing time = 0.7355484867835195
#   Normalized Error = 0.5547071011767456
#
# Match 134:
#   Recurrence time = 0.006 Myr
#   Amin = -0.9
#   Amax = 1.5
#   Model mean(|x|) = 4.360304511918133
#   Model std(|x|) = 3.2357441576116783
#   Model reversal frequency = 1.131724374017609 per Myr
#   Proportion reversing time = 0.7448681680804918
#   Normalized Error = 0.5949537702231041
#
# Match 147:
#   Recurrence time = 0.006 Myr
#   Amin = -0.9
#   Amax = 1.7
#   Model mean(|x|) = 6.0623774837615
#   Model std(|x|) = 3.694455116857004
#   Model reversal frequency = 1.098438363017091 per Myr
#   Proportion reversing time = 0.4595892441156014
#   Normalized Error = 0.6353240524638596
#
# Match 96:
#   Recurrence time = 0.006 Myr
#   Amin = -0.7
#   Amax = 0.9
#   Model mean(|x|) = 1.8656170960198186
#   Model std(|x|) = 1.558916893028072
#   Model reversal frequency = 4.127465364064221 per Myr
#   Proportion reversing time = 0.5265120898939731
#   Normalized Error = 0.6482392517331262
#
# Match 109:
#   Recurrence time = 0.006 Myr
#   Amin = -0.7
#   Amax = 1.1
#   Model mean(|x|) = 2.859127829533505
#   Model std(|x|) = 2.323842763532087
#   Model reversal frequency = 1.531156506023824 per Myr
#   Proportion reversing time = 0.7041263349091924
#   Normalized Error = 0.6572666630066405
#
# Match 110:
#   Recurrence time = 0.006 Myr
#   Amin = -0.5
#   Amax = 1.1
#   Model mean(|x|) = 4.755349521392562
#   Model std(|x|) = 2.6701712329320477
#   Model reversal frequency = 0.7988642640124299 per Myr
#   Proportion reversing time = 0.5600391081761753
#   Normalized Error = 0.6697648452346978

# %%
#Best Guess
idx =  top_10_indices[1]
best_idx = CartesianIndices(errors)[idx]
best_k, best_l, best_m = Tuple(best_idx)

best_recurrence = recurrences[best_k]
best_Amin = Amin_vals[best_l]
best_Amax = Amax_vals[best_m]

println("\nMatch $(idx):")
println("  Recurrence time = $(best_recurrence) Myr")
println("  Amin = $(best_Amin)")
println("  Amax = $(best_Amax)")
println("  Model mean(|x|) = ", x_means[best_k, best_l, best_m])
println("  Model std(|x|) = ", x_stds[best_k, best_l, best_m])
println("  Model reversal frequency = ", rev_freqs[best_k, best_l, best_m], " per Myr")
println("  Proportion reversing time = ", props[best_k, best_l, best_m])
println("  Normalized Error = ", errors[best_k, best_l, best_m])
# Out:
# Match 146:
#   Recurrence time = 0.006 Myr
#   Amin = -1.1
#   Amax = 1.7
#   Model mean(|x|) = 3.9909164527573897
#   Model std(|x|) = 3.4868146711757375
#   Model reversal frequency = 3.9610353090616317 per Myr
#   Proportion reversing time = 0.22283146628475456
#   Normalized Error = 0.15237568913763697

# %%
using Plots

Amax_array = collect(Amax_vals)
Amin_array = collect(Amin_vals)

# Choose your variable to plot — options: :x_means, :x_stds, :rev_freqs
target = :rev_freqs
title_base = "rev freq"
cbar_label = "rev freq"
Z = getfield(Main, target)

# Get global color limits across all recurrences
zmin = minimum(Z)
zmax = maximum(Z)

# Plot layout
ncols = 5  # Adjust to fit screen better
nrows = ceil(Int, length(recurrences) / ncols)

plots = []

for k in 1:length(recurrences)
    rec = recurrences[k]
    zslice = Z[k, :, :]  # (Amin, Amax)

    p = contour(Amax_array, Amin_array, zslice,
        xlabel = "Amax",
        ylabel = "Amin",
        title = "$(title_base), R = $(round(rec, digits=3))",
        colorbar = false,
        clims = (zmin, zmax))
    push!(plots, p)
end

# Combine and add a colorbar to one plot for legend
plot(plots..., layout = (nrows, ncols), size = (250 * ncols, 250 * nrows))

# %%
using Plots
using Colors

Amax_array = collect(Amax_vals)
Amin_array = collect(Amin_vals)

# Choose your variable to plot — options: :x_means, :x_stds, :rev_freqs
target = :rev_freqs
title_base = "rev freq"
cbar_label = "rev freq"
Z = getfield(Main, target)

special_val = 999.0
colors_normal = cgrad(:viridis, 256)

# Fixed color scale for all plots
clim_lo = 0.0
clim_hi = 20.0

ncols = 5
nrows = ceil(Int, length(recurrences) / ncols)
plots = []

dx = mean(diff(Amax_array))
dy = mean(diff(Amin_array))

for k in 1:length(recurrences)
    rec = recurrences[k]
    zslice = Z[k, :, :]

    # Mask special values for base heatmap
    z_masked = copy(zslice)
    is_special = z_masked .== special_val
    z_masked[is_special] .= NaN

    # Create base heatmap
    p = heatmap(
        Amax_array,
        Amin_array,
        z_masked,
        xlabel = "Amax",
        ylabel = "Amin",
        title = "$(title_base), R = $(round(rec, digits=3))",
        clims = (clim_lo, clim_hi),
        color = colors_normal,
        colorbar = false,
        aspect_ratio = :equal
    )

    # Overlay red squares for 999s
    for i in 1:length(Amin_array), j in 1:length(Amax_array)
        if is_special[i, j]
            x = Amax_array[j]
            y = Amin_array[i]
            shape = Shape([x - dx/2, x + dx/2, x + dx/2, x - dx/2],
                          [y - dy/2, y - dy/2, y + dy/2, y + dy/2])
            plot!(p, shape, color = RGBA(1.0, 0.0, 0.0, 1.0), legend = false)
        end
    end

    push!(plots, p)
end

# Combine subplots into grid with a shared colorbar
plot(plots..., layout = (nrows, ncols),
     size = (250 * ncols, 250 * nrows),
     colorbar_title = cbar_label)

# %%
using Plots

Amax_array = collect(Amax_vals)
Amin_array = collect(Amin_vals)

# Choose your variable to plot — options: :x_means, :x_stds, :rev_freqs
target = :errors
title_base = "Errors func"
cbar_label = "error func"
Z = getfield(Main, target)

# Get global color limits across all recurrences
zmin = minimum(Z)
zmax = maximum(Z)

# Plot layout
ncols = 5  # Adjust to fit screen better
nrows = ceil(Int, length(recurrences) / ncols)

plots = []

for k in 1:length(recurrences)
    rec = recurrences[k]
    zslice = Z[k, :, :]  # (Amin, Amax)

    p = contour(Amax_array, Amin_array, zslice,
        xlabel = "Amax",
        ylabel = "Amin",
        title = "$(title_base), R = $(round(rec, digits=3))",
        colorbar = false,
        clims = (0, 5))
    push!(plots, p)
end

# Combine and add a colorbar to one plot for legend
plot(plots..., layout = (nrows, ncols), size = (250 * ncols, 250 * nrows))

# %%
using Statistics
using Plots

# Compute minimum error per recurrence slice, ignoring NaNs
min_errors = [
    minimum(filter(!isnan, vec(errors[i, :, :])))
    for i in 1:length(recurrences)
]

ymin = 0
ymax = maximum(min_errors)  # Assumes no all-NaN slices

# Plot min error vs recurrence rate
plot(
    recurrences, min_errors,
    xlabel = "Recurrence Interval (Myr)",
    ylabel = "Minimum error",
    title = "Min Error vs Recurrence Interval",
    marker = :circle,
    legend = false,
    ylim = (ymin, ymax+0.1)
)

# %%
using Plots

Amax_array = collect(Amax_vals)
Amin_array = collect(Amin_vals)
recurrences_array = collect(recurrences)

target = :errors
title_base = "Error"
cbar_label = "error func"
Z = getfield(Main, target)

zvals = filter(!isnan, vec(Z))
zmin = minimum(zvals)
zmax = maximum(zvals)

ncols = 5
nrows = ceil(Int, length(Amin_array) / ncols)
plots = []

for j in 1:length(Amin_array)
    zslice = Z[:, j, :]  # (recurrence, Amax)

    p = contour(
        Amax_array, recurrences_array, zslice,
        xlabel = "Amax",
        ylabel = "Recurrence rate",
        title = "$(title_base), Amin = $(round(Amin_array[j], digits=3))",
        colorbar = false,
        clims = (0, 5)
    )
    push!(plots, p)
end

# Combine and add a colorbar to one plot for legend
plot(plots..., layout = (nrows, ncols), size = (250 * ncols, 250 * nrows))

# %%
using Statistics
using Plots

# Compute minimum error per recurrence slice, ignoring NaNs
min_errors = [
    minimum(filter(!isnan, vec(errors[:, i, :])))
    for i in 1:length(Amin_vals)
]

ymin = 0
ymax = maximum(min_errors)  # Assumes no all-NaN slices

# Plot min error vs Amin
plot(
    Amin_vals, min_errors,
    xlabel = "Amin",
    ylabel = "Minimum error",
    title = "Min Error vs Amin",
    marker = :circle,
    legend = false,
    ylim = (ymin, ymax+0.1)
)

# %%
plots = []

for k in 1:length(Amax_array)
    zslice = Z[:, :, k]  # (recurrence, Amin)

    p = contour(
        Amin_array, recurrences_array, zslice,
        xlabel = "Amin",
        ylabel = "Recurrence rate",
        title = "$(title_base), Amax = $(round(Amax_array[k], digits=3))",
        colorbar = false,
        clims = (zmin, 5)
    )
    push!(plots, p)
end

nrows = ceil(Int, length(Amax_array) / ncols)


plot(plots..., layout = (nrows, ncols), size = (250 * ncols, 250 * nrows))

# %%
using Statistics
using Plots

# Compute minimum error per recurrence slice, ignoring NaNs
min_errors = [
    minimum(filter(!isnan, vec(errors[:, :, i])))
    for i in 1:length(Amax_vals)
]

ymin = 0
ymax = maximum(min_errors)  # Assumes no all-NaN slices

# Plot min error vs Amin
plot(
    Amax_vals, min_errors,
    xlabel = "Amax",
    ylabel = "Minimum error",
    title = "Min Error vs Amax",
    marker = :circle,
    legend = false,
    ylim = (ymin, ymax+0.1)
)

# %%
idx = top_10_indices[1]
best_idx = CartesianIndices(errors)[idx]
best_k, best_l, best_m = Tuple(best_idx)

best_recurrence = recurrences[best_k]
best_Amin = Amin_vals[best_l]
best_Amax = Amax_vals[best_m]

println("\nMatch $(idx):")
println("  Recurrence time = $(best_recurrence) Myr")
println("  Amin = $(best_Amin)")
println("  Amax = $(best_Amax)")
println("  Model mean(|x|) = ", x_means[best_k, best_l, best_m])
println("  Model std(|x|) = ", x_stds[best_k, best_l, best_m])
println("  Model reversal frequency = ", rev_freqs[best_k, best_l, best_m], " per Myr")
println("  Proportion reversing time = ", props[best_k, best_l, best_m])
println("  Normalized Error = ", errors[best_k, best_l, best_m])

# %% [markdown]
# ## "Best" run

# %%
recurrence = best_recurrence
nevents = 22000;
tevent = rand(Exponential(recurrence),nevents);  # Poisson event times

# plot distribution of event times
println("mean recurrence time = ",mean(tevent)," Myr")
histogram(tevent,label="event times",xlabel="event time (Myr)",ylabel="Number")


Amax = best_Amax
Amin = best_Amin
amp_p = rand(Uniform(Amin,Amax),nevents)

# include random (white) noise
np = rand(Normal(),2*nevents); #called wi in paper
qp = 45;       #  gaussian noise variance

# set level of quenching
x0 = 5.0;

# allocate memory for solution
x = zeros(2*nevents);
t = zeros(2*nevents);


# decay rate for dipole (gamma = 1/tau)
gamma = 0.025 * 1000;    # convert to Myr

# initial condition
t[1] = 0.0;
x[1] = 5.0;
j = 2;

# integrate of number of events
for i = j : nevents
    
    # magnetic diffusion over half time step dt
    dt = tevent[i]/2.0;
    t[j] = t[j-1] + dt;
    gp = exp(-x[j-1]^2/1.8^2);  # x-dependence of gaussian noise
    x[j] = x[j-1] * exp(-gamma * dt) + np[j]*sqrt(gp*qp*dt);;
    
    # magnetic diffusion over remaining time step
    j += 1;
    t[j] = t[j-1] + dt;
    x[j] = x[j-1] * exp(-gamma * dt)
    
    # evaluate quenching
    fp = 1.0/ (1.0 + (x[j]/x0)^2);
    gp = exp(-x[j]^2/1.8^2);
    
    # add event and random noise
    x[j] += amp_p[i] * x[j] * fp + np[j]*sqrt(gp*qp*dt); 
    j+= 1;
    
end
t[end] = t[end-1]
x[end] = x[end-1]
println("recurrence = ", recurrence, " Myr ", " mean x = ",mean(abs.(x))," std x = ",std(abs.(x)))
mean_x = mean(abs.(x))
std_x = std(abs.(x))

#Calculate reversal rate
cutoff = mean_x - std_x
prev_rev_rate = Inf
tol = 0.1 # 
max_iters = 10

for n in 1:max_iters
    intervals, event_types, prop, mean_exc_x, std_exc_x, rev_rate = analyze_x_intervals(t, x, cutoff)
    println("rev rate: ", rev_rate, " per Myr")
    if abs(rev_rate - prev_rev_rate) < tol
        break
    end
    cutoff = mean_exc_x - std_exc_x
    prev_rev_rate = rev_rate
end
println("final rev rate: ", rev_rate, " per Myr")
println("proportion reversing: ", prop)

# plot time series 
idecimate = 1;
plot(t[1:idecimate:end],(x[1:idecimate:end]),
label="x",xlabel="time (Myr)",
ylabel="Dipole Moment  (1.0e22 A m2)"
)

# %%
# plot time series 
idecimate = 1;
plot(t[1:idecimate:end],(x[1:idecimate:end]),
label="x",xlabel="time (Myr)",
ylabel="Dipole Moment  (1.0e22 A m2)",
    xlim = (10,20)
)

# %% [markdown]
# ## Testing example

# %%
recurrence = 0.006
nevents = 10000;
tevent = rand(Exponential(recurrence),nevents);  # Poisson event times

# plot distribution of event times
println("mean recurrence time = ",mean(tevent)," Myr")
histogram(tevent,label="event times",xlabel="event time (Myr)",ylabel="Number")


Amax = 0.95
Amin = -1.25
amp_p = rand(Uniform(Amin,Amax),nevents)

# include random (white) noise
np = rand(Normal(),2*nevents); #called wi in paper
qp = 100;       #  gaussian noise variance

# set level of quenching
x0 = 5.0;

# allocate memory for solution
x = zeros(2*nevents);
t = zeros(2*nevents);


# decay rate for dipole (gamma = 1/tau)
gamma = 0.025 * 1000;    # convert to Myr

# initial condition
t[1] = 0.0;
x[1] = 5.0;
j = 2;

# integrate of number of events
for i = j : nevents
    
    # magnetic diffusion over half time step dt
    dt = tevent[i]/2.0;
    t[j] = t[j-1] + dt;
    gp = exp(-x[j-1]^2/1.8^2);  # x-dependence of gaussian noise
    x[j] = x[j-1] * exp(-gamma * dt) + np[j]*sqrt(gp*qp*dt);;
    
    # magnetic diffusion over remaining time step
    j += 1;
    t[j] = t[j-1] + dt;
    x[j] = x[j-1] * exp(-gamma * dt)
    
    # evaluate quenching
    fp = 1.0/ (1.0 + (x[j]/x0)^2);
    gp = exp(-x[j]^2/1.8^2);
    
    # add event and random noise
    x[j] += amp_p[i] * x[j] * fp + np[j]*sqrt(gp*qp*dt); 
    j+= 1;
    
end
t[end] = t[end-1]
x[end] = x[end-1]
println("recurrence = ", recurrence, " Myr ", " Amax = ", Amax, " Amin = ", Amin,  " mean x = ",mean(abs.(x))," std x = ",std(abs.(x)))
mean_x = mean(abs.(x))
std_x = std(abs.(x))

#Calculate reversal rate
cutoff = mean_x - std_x
prev_rev_rate = Inf
tol = 0.1 # 
max_iters = 10

for n in 1:max_iters
    intervals, event_types, prop, mean_exc_x, std_exc_x, rev_rate = analyze_x_intervals(t, x, cutoff)
    println("rev rate: ", rev_rate, " per Myr")
    if abs(rev_rate - prev_rev_rate) < tol
        break
    end
    cutoff = mean_exc_x - std_exc_x
    prev_rev_rate = rev_rate
end
println("final rev rate: ", rev_rate, " per Myr")
println("proportion reversing: ", prop)

# plot time series 
idecimate = 1;
plot(t[1:idecimate:end],(x[1:idecimate:end]),
label="x",xlabel="time (Myr)",
ylabel="Dipole Moment  (1.0e22 A m2)"
)

# %%
# plot time series 
idecimate = 1;
plot(t[1:idecimate:end],(x[1:idecimate:end]),
label="x",xlabel="time (Myr)",
ylabel="Dipole Moment  (1.0e22 A m2)",
    xlim = (10,15), 
   # ylim = (-10, 10)
)

# %%
using LaTeXStrings

h = fit(Histogram, x, nbins = 100)
plot(
    h,
    label = "x(t)",
    xlabel = L"Dipole moment, $10^{22}\ \mathrm{Am}^2$",
    ylabel = L"Frequency"
)

# %%
# elapsed = @elapsed begin

#     recurrences =0.006 # average recurrence time (Myr)
#     Amin_vals = -1.5:0.02:0
#     Amax_vals = 0:0.02:1.5
    
#     # Create an empty matrix to store results with NaNs
#     x_means = fill(NaN, length(recurrences), length(Amin_vals), length(Amax_vals))
#     x_stds = fill(NaN, length(recurrences), length(Amin_vals), length(Amax_vals))
#     rev_freqs = fill(NaN, length(recurrences), length(Amin_vals), length(Amax_vals))
#     props = fill(NaN, length(recurrences), length(Amin_vals), length(Amax_vals))
    
#     for (k, recurrence) in enumerate(recurrences)
    
#         nevents = 5000;
#         tevent = rand(Exponential(recurrence),nevents);  # Poisson event times
    
#         # plot distribution of event times
#         println("mean recurrence time = ",mean(tevent)," Myr")
        
#         for (l, Amin) in enumerate(Amin_vals)
#             for (m, Amax) in enumerate(Amax_vals)
#                 if Amin >= Amax 
#                     #All outputs will remain NaN
#                     continue
#                 end    
        
#                 amp_p = rand(Uniform(Amin,Amax),nevents);
            
#                 # include random (white) noise
#                 np = rand(Normal(),2*nevents); #called wi in paper
#                 qp = 45;       #  gaussian noise variance
                
#                 # set level of quenching
#                 x0 = 5.0;
            
#                 # allocate memory for solution
#                 x = zeros(2*nevents);
#                 t = zeros(2*nevents);
                
                
#                 # decay rate for dipole (gamma = 1/tau)
#                 gamma = 0.025 * 1000;    # convert to Myr
                
#                 # initial condition
#                 t[1] = 0.0;
#                 x[1] = 5.0;
#                 j = 2;
                
#                 # integrate of number of events
#                 for i = j : nevents
                    
#                     # magnetic diffusion over half time step dt
#                     dt = tevent[i]/2.0;
#                     t[j] = t[j-1] + dt;
#                     gp = exp(-x[j-1]^2/1.8^2);  # x-dependence of gaussian noise
#                     x[j] = x[j-1] * exp(-gamma * dt) + np[j]*sqrt(gp*qp*dt);;
                    
#                     # magnetic diffusion over remaining time step
#                     j += 1;
#                     t[j] = t[j-1] + dt;
#                     x[j] = x[j-1] * exp(-gamma * dt)
                    
#                     # evaluate quenching
#                     fp = 1.0/ (1.0 + (x[j]/x0)^2);
#                     gp = exp(-x[j]^2/1.8^2);
                    
#                     # add event and random noise
#                     x[j] += amp_p[i] * x[j] * fp + np[j]*sqrt(gp*qp*dt); 
#                     j+= 1;
                    
                    
#                 end
#                 t[end] = t[end-1]
#                 x[end] = x[end-1]
#                 mean_x = mean(abs.(x))
#                 std_x = std(abs.(x))
#                 println("Amin = ", Amin, " Amax = " , Amax, " R = ", recurrence,  " mean x = ",mean_x," std x = ",std_x)
#                 x_means[k,l,m] = mean_x
#                 x_stds[k,l,m] = std_x
                
#                 #Calculate reversal rate
#                 cutoff = mean_x - std_x
#                 prev_rev_rate = Inf
#                 tol = 0.1 #tolerance for reversal rate change
#                 max_iters = 10
                
#                 for n in 1:max_iters
#                     intervals, event_types, prop, mean_exc_x, std_exc_x, rev_rate = analyze_x_intervals(t, x, cutoff)
#                     println("rev rate: ", rev_rate, " per Myr")
#                     if abs(rev_rate - prev_rev_rate) < tol
#                         break
#                     end
#                     cutoff = mean_exc_x - std_exc_x
#                     prev_rev_rate = rev_rate
#                 end
#                             rev_freqs[k,l,m] = rev_rate
#                 println("final rev rate: ", rev_rate, " per Myr")
#                 props[k,l,m] = prop
#             end
#         end   
    
#     end
# end

# println("Elapsed time: $(round(elapsed, digits=3)) seconds")

# %%
using Plots
using Colors

Amax_array = collect(Amax_vals)
Amin_array = collect(Amin_vals)

# Choose variable to plot
target = :rev_freqs
title_base = "rev freq"
cbar_label = "Rev freq (Myr⁻¹)"
Z = getfield(Main, target)

special_val = 999.0
colors_normal = cgrad(:viridis, 256)

# Color limits
clim_lo = 0.0
clim_hi = 20.0

# Select one recurrence
k = 1
rec = recurrences[k]
zslice = Z[k, :, :]

# Prepare masked data
z_masked = copy(zslice)
is_special = z_masked .== special_val
z_masked[is_special] .= NaN

# Cell size for overlay
dx = mean(diff(Amax_array))
dy = mean(diff(Amin_array))
runtime = rec *nevents #in myr
# Create heatmap
p = heatmap(
    Amax_array,
    Amin_array,
    z_masked,
    xlabel = "Amax",
    ylabel = "Amin",
    #title = "$(title_base), R = $(round(rec, digits=3))",
    clims = (clim_lo, clim_hi),
    color = colors_normal,
    colorbar_title = cbar_label,
    aspect_ratio = :equal,
    size = (600, 500),
    title = "$(title_base), R = $(round(rec, digits=3)), runtime=$(runtime) Myr, qp=$(qp)",
)

# Overlay red squares
for i in 1:length(Amin_array), j in 1:length(Amax_array)
    if is_special[i, j]
        x = Amax_array[j]
        y = Amin_array[i]
        shape = Shape([x - dx/2, x + dx/2, x + dx/2, x - dx/2],
                      [y - dy/2, y - dy/2, y + dy/2, y + dy/2])
        plot!(p, shape, color = RGBA(1.0, 0.0, 0.0, 1.0), legend = false)
    end
end

p

# %%
# elapsed = @elapsed begin

#     recurrences =0.006 # average recurrence time (Myr)
#     Amin_vals = -1.5:0.02:0
#     Amax_vals = 0.5:0.01:1
    
#     # Create an empty matrix to store results with NaNs
#     x_means = fill(NaN, length(recurrences), length(Amin_vals), length(Amax_vals))
#     x_stds = fill(NaN, length(recurrences), length(Amin_vals), length(Amax_vals))
#     rev_freqs = fill(NaN, length(recurrences), length(Amin_vals), length(Amax_vals))
#     props = fill(NaN, length(recurrences), length(Amin_vals), length(Amax_vals))
    
#     for (k, recurrence) in enumerate(recurrences)
    
#         nevents = 5000;
#         tevent = rand(Exponential(recurrence),nevents);  # Poisson event times
    
#         # plot distribution of event times
#         println("mean recurrence time = ",mean(tevent)," Myr")
        
#         for (l, Amin) in enumerate(Amin_vals)
#             for (m, Amax) in enumerate(Amax_vals)
#                 if Amin >= Amax 
#                     #All outputs will remain NaN
#                     continue
#                 end    
        
#                 amp_p = rand(Uniform(Amin,Amax),nevents);
            
#                 # include random (white) noise
#                 np = rand(Normal(),2*nevents); #called wi in paper
#                 qp = 45;       #  gaussian noise variance
                
#                 # set level of quenching
#                 x0 = 5.0;
            
#                 # allocate memory for solution
#                 x = zeros(2*nevents);
#                 t = zeros(2*nevents);
                
                
#                 # decay rate for dipole (gamma = 1/tau)
#                 gamma = 0.025 * 1000;    # convert to Myr
                
#                 # initial condition
#                 t[1] = 0.0;
#                 x[1] = 5.0;
#                 j = 2;
                
#                 # integrate of number of events
#                 for i = j : nevents
                    
#                     # magnetic diffusion over half time step dt
#                     dt = tevent[i]/2.0;
#                     t[j] = t[j-1] + dt;
#                     gp = exp(-x[j-1]^2/1.8^2);  # x-dependence of gaussian noise
#                     x[j] = x[j-1] * exp(-gamma * dt) + np[j]*sqrt(gp*qp*dt);;
                    
#                     # magnetic diffusion over remaining time step
#                     j += 1;
#                     t[j] = t[j-1] + dt;
#                     x[j] = x[j-1] * exp(-gamma * dt)
                    
#                     # evaluate quenching
#                     fp = 1.0/ (1.0 + (x[j]/x0)^2);
#                     gp = exp(-x[j]^2/1.8^2);
                    
#                     # add event and random noise
#                     x[j] += amp_p[i] * x[j] * fp + np[j]*sqrt(gp*qp*dt); 
#                     j+= 1;
                    
                    
#                 end
#                 t[end] = t[end-1]
#                 x[end] = x[end-1]
#                 mean_x = mean(abs.(x))
#                 std_x = std(abs.(x))
#                 println("Amin = ", Amin, " Amax = " , Amax, " R = ", recurrence,  " mean x = ",mean_x," std x = ",std_x)
#                 x_means[k,l,m] = mean_x
#                 x_stds[k,l,m] = std_x
                
#                 #Calculate reversal rate
#                 cutoff = mean_x - std_x
#                 prev_rev_rate = Inf
#                 tol = 0.1 #tolerance for reversal rate change
#                 max_iters = 10
                
#                 for n in 1:max_iters
#                     intervals, event_types, prop, mean_exc_x, std_exc_x, rev_rate = analyze_x_intervals(t, x, cutoff)
#                     println("rev rate: ", rev_rate, " per Myr")
#                     if abs(rev_rate - prev_rev_rate) < tol
#                         break
#                     end
#                     cutoff = mean_exc_x - std_exc_x
#                     prev_rev_rate = rev_rate
#                 end
#                             rev_freqs[k,l,m] = rev_rate
#                 println("final rev rate: ", rev_rate, " per Myr")
#                 props[k,l,m] = prop
#             end
#         end   
    
#     end
# end

# println("Elapsed time: $(round(elapsed, digits=3)) seconds")

# %%
# using Plots
# using Colors

# Amax_array = collect(Amax_vals)
# Amin_array = collect(Amin_vals)

# # Choose variable to plot
# target = :rev_freqs
# title_base = "rev freq"
# cbar_label = "rev freq"
# Z = getfield(Main, target)

# special_val = 999.0
# colors_normal = cgrad(:viridis, 256)

# # Color limits
# clim_lo = 0.0
# clim_hi = 20.0

# # Select one recurrence
# k = 1
# rec = recurrences[k]
# zslice = Z[k, :, :]

# # Prepare masked data
# z_masked = copy(zslice)
# is_special = z_masked .== special_val
# z_masked[is_special] .= NaN

# # Cell size for overlay
# dx = mean(diff(Amax_array))
# dy = mean(diff(Amin_array))

# # Create heatmap
# p = heatmap(
#     Amax_array,
#     Amin_array,
#     z_masked,
#     xlabel = "Amax",
#     ylabel = "Amin",
#     title = "$(title_base), R = $(round(rec, digits=3))",
#     clims = (clim_lo, clim_hi),
#     color = colors_normal,
#     colorbar_title = cbar_label,
#     #aspect_ratio = :equal,
#     size = (600, 500)
# )

# # Overlay red squares
# for i in 1:length(Amin_array), j in 1:length(Amax_array)
#     if is_special[i, j]
#         x = Amax_array[j]
#         y = Amin_array[i]
#         shape = Shape([x - dx/2, x + dx/2, x + dx/2, x - dx/2],
#                       [y - dy/2, y - dy/2, y + dy/2, y + dy/2])
#         plot!(p, shape, color = RGBA(1.0, 0.0, 0.0, 1.0), legend = false)
#     end
# end

# p

# %%
# save to file
save_file = true
      
if save_file
    open("dipole_3000_mod3.txt","w")  do io
        writedlm(io,[t x])
    end
end

# %% [markdown]
# Plot a histogram of dipole moment

# %%
using LaTeXStrings

h = fit(Histogram, x, nbins = 100)
plot(
    h,
    label = "x(t)",
    xlabel = L"Dipole moment, $10^{22}\ \mathrm{Am}^2$",
    ylabel = L"Frequency"
)

# %% [markdown]
# Evaluates the mean amplitudes $<A>$, $<A^2>$ and $<A^3>$. Mean and second moment appear in the Fokker-Planck equation.

# %%
function moments(A,rate)
#
# evaluates moments of amplitudes <A>, <A2>, <A3>.
#
# input
# A  - nominal amplitude of events
# rate - rate of Poisson process

# output
# Ap  - moments of amplitudes Ap[1st,2nd,3rd]

# maximum and minimum amplitudes
Apmin = 0.47 * A;   #close to earlier values
Apmax = 4.14 * A;

An = zeros(3);

An[1] = rate*(Apmin+Apmax)/2.0;
An[2] = rate*(Apmax^2 + Apmin^2 + Apmax*Apmin)/3.0;
An[3] = rate*(Apmax + Apmin)*(Apmax^2+Apmin^2)/4.0;



return An

end

# %% [markdown]
# Compute drift $D_1$ and diffusion $D_2$ coefficients

# %%
rate = 1/recurrence
A=1
An = moments(A,rate)

# define range of x for plotting
xplot = (0 : 0.1 : 10.0);
D1 = zeros(length(xplot))
D2 = zeros(length(xplot))
D3 = zeros(length(xplot))

# compute D1 and D2 at plotting points
for i = 1 : length(xplot)
    f = 1.0 / (1.0 + (xplot[i]/x0)^2);
    g = exp(-xplot[i]^2/1.8^2)
    D1[i] = -gamma*xplot[i] + An[1]*xplot[i]*f;
    D2[i] = 0.5*An[2]*(xplot[i]^2)*(f^2) + 0.5 * qp*g;
    D3[i] = (1/6.0) * An[3]*(xplot[i]^3)*(f^3);
end

plot(xplot,D1,label="D1",xlabel="Dipole moment [1.0e22 A m2]",ylabel="Coefficient (in Myr)")
plot!(xplot,D2,label="D2")
#plot(xplot,D3)

# %% [markdown]
# Save a plot of the drift and diffusion coefficients

# %%
savefig("Drift&Diffusion.pdf")

# %% [markdown]
# ## Interpolate and Resample to even timesteps

# %%
using Interpolations

function resample_linear(t::Vector{Float64}, x::Vector{Float64},
                         dt::Float64)

    # Create linear interpolation
    itp = LinearInterpolation(t, x, extrapolation_bc=Line())

    # Create uniform time vector using sampling frequency
    t_min = first(t)
    t_max = last(t)
    t_uniform = collect(t_min:dt:t_max)

    # Interpolate x at uniform time points
    x_uniform = itp.(t_uniform)

    return t_uniform, x_uniform
end

# %%
t_resampled, x_resampled = resample_linear(t, x, 0.01)

# %%
filename = "dipole_3000_resampled_Amax$(Amax)_Amin$(Amin)_R$(recurrence)_10kyr.txt"

# %%
filename = "dipole_3000_resampled_Amax$(Amax)_Amin$(Amin)_R$(recurrence)_10kyr.txt"
open(filename,"w")  do io
    writedlm(io,[t_resampled x_resampled])
end
g10 = x_resampled *1.0e22 *1.0e-7/(6371200.0^3)* 1.0e6 #returns values in microT
open(filename,"w")  do io
    writedlm(io,[t_resampled g10])
end

# %%
function convert_VDM_to_g10(vdm::Float64)
    #Earth's radius is 6371.2 km
    g10 = vdm *1.0e-7/(6371200.0^3)
    return g10
end

# %%
function convert_g10_to_VDM(g10::Float64)
    #Earth's radius is 6371.2 km
    vdm  = g10 *(6371200.0^3)*1.0e7
    return vdm
end

# %%
g10 = x_resampled *1.0e22 *1.0e-7/(6371200.0^3)* 1.0e6 #returns values in microT

# %%
open(filename,"w")  do io
    writedlm(io,[t_resampled g10])
end

# %%
idx = top_10_indices[1]
best_idx = CartesianIndices(errors)[idx]
best_k, best_l, best_m = Tuple(best_idx)

best_recurrence = recurrences[best_k]
best_Amin = Amin_vals[best_l]
best_Amax = Amax_vals[best_m]

println("\nMatch $(idx):")
println("  Recurrence time = $(best_recurrence) Myr")
println("  Amin = $(best_Amin)")
println("  Amax = $(best_Amax)")
println("  Model mean(|x|) = ", x_means[best_k, best_l, best_m])
println("  Model std(|x|) = ", x_stds[best_k, best_l, best_m])
println("  Model reversal frequency = ", rev_freqs[best_k, best_l, best_m], " per Myr")
println("  Proportion reversing time = ", props[best_k, best_l, best_m])
println("  Normalized Error = ", errors[best_k, best_l, best_m])

# %%
recurrence = 0.0052
nevents = 20000;
tevent = rand(Exponential(recurrence),nevents);  # Poisson event times

# plot distribution of event times
println("mean recurrence time = ",mean(tevent)," Myr")
histogram(tevent,label="event times",xlabel="event time (Myr)",ylabel="Number")


Amax = 1.225
Amin = -0.6
amp_p = rand(Uniform(Amin,Amax),nevents)

# include random (white) noise
np = rand(Normal(),2*nevents); #called wi in paper
qp = 45;       #  gaussian noise variance

# set level of quenching
x0 = 5.0;

# allocate memory for solution
x = zeros(2*nevents);
t = zeros(2*nevents);


# decay rate for dipole (gamma = 1/tau)
gamma = 0.025 * 1000;    # convert to Myr

# initial condition
t[1] = 0.0;
x[1] = 5.0;
j = 2;

# integrate of number of events
for i = j : nevents
    
    # magnetic diffusion over half time step dt
    dt = tevent[i]/2.0;
    t[j] = t[j-1] + dt;
    gp = exp(-x[j-1]^2/1.8^2);  # x-dependence of gaussian noise
    x[j] = x[j-1] * exp(-gamma * dt) + np[j]*sqrt(gp*qp*dt);;
    
    # magnetic diffusion over remaining time step
    j += 1;
    t[j] = t[j-1] + dt;
    x[j] = x[j-1] * exp(-gamma * dt)
    
    # evaluate quenching
    fp = 1.0/ (1.0 + (x[j]/x0)^2);
    gp = exp(-x[j]^2/1.8^2);
    
    # add event and random noise
    x[j] += amp_p[i] * x[j] * fp + np[j]*sqrt(gp*qp*dt); 
    j+= 1;
    
end
t[end] = t[end-1]
x[end] = x[end-1]
println("recurrence = ", recurrence, " Myr ", " mean x = ",mean(abs.(x))," std x = ",std(abs.(x)))
mean_x = mean(abs.(x))
std_x = std(abs.(x))

#Calculate reversal rate
cutoff = mean_x - std_x
prev_rev_rate = Inf
tol = 0.1 # 
max_iters = 10

for n in 1:max_iters
    intervals, event_types, prop, mean_exc_x, std_exc_x, rev_rate = analyze_x_intervals(t, x, cutoff)
    println("rev rate: ", rev_rate, " per Myr")
    if abs(rev_rate - prev_rev_rate) < tol
        break
    end
    cutoff = mean_exc_x - std_exc_x
    prev_rev_rate = rev_rate
end
println("final rev rate: ", rev_rate, " per Myr")
println("proportion reversing: ", prop)

# plot time series 
idecimate = 1;
plot(t[1:idecimate:end],(x[1:idecimate:end]),
label="x",xlabel="time (Myr)",
ylabel="Dipole Moment  (1.0e22 A m2)"
)

# %%
#plot time series 
idecimate = 1;
plot(t[1:idecimate:end],(x[1:idecimate:end]),
    label="x",xlabel="time (Myr)",
    #xlim=(0.25, 0.4)
    ylabel="Dipole Moment  (1.0e22 A m2)"
)

# %% [markdown]
# ## Run and save to file

# %%
recurrence = 0.006
nevents = 20000;
tevent = rand(Exponential(recurrence),nevents);  # Poisson event times

# plot distribution of event times
println("mean recurrence time = ",mean(tevent)," Myr")
histogram(tevent,label="event times",xlabel="event time (Myr)",ylabel="Number")


Amax = 0.6
Amin = -1.5
amp_p = rand(Uniform(Amin,Amax),nevents)

# include random (white) noise
np = rand(Normal(),2*nevents); #called wi in paper
qp = 45;       #  gaussian noise variance

# set level of quenching
x0 = 5.0;

# allocate memory for solution
x = zeros(2*nevents);
t = zeros(2*nevents);


# decay rate for dipole (gamma = 1/tau)
gamma = 0.025 * 1000;    # convert to Myr

# initial condition
t[1] = 0.0;
x[1] = 5.0;
j = 2;

# integrate of number of events
for i = j : nevents
    
    # magnetic diffusion over half time step dt
    dt = tevent[i]/2.0;
    t[j] = t[j-1] + dt;
    gp = exp(-x[j-1]^2/1.8^2);  # x-dependence of gaussian noise
    x[j] = x[j-1] * exp(-gamma * dt) + np[j]*sqrt(gp*qp*dt);;
    
    # magnetic diffusion over remaining time step
    j += 1;
    t[j] = t[j-1] + dt;
    x[j] = x[j-1] * exp(-gamma * dt)
    
    # evaluate quenching
    fp = 1.0/ (1.0 + (x[j]/x0)^2);
    gp = exp(-x[j]^2/1.8^2);
    
    # add event and random noise
    x[j] += amp_p[i] * x[j] * fp + np[j]*sqrt(gp*qp*dt); 
    j+= 1;
    
end
t[end] = t[end-1]
x[end] = x[end-1]
println("Amin = ", Amin, " Amax = " , Amax, " R = ", recurrence,  " mean x = ",mean_x," std x = ",std_x)
mean_x = mean(abs.(x))
std_x = std(abs.(x))
median_x = median(abs.(x))
iqr_x = quantile(abs.(x), 0.75) - quantile(abs.(x), 0.25)
println("recurrence = ", recurrence, " Myr ",
        " mean x = ", mean_x,
        " std x = ", std_x,
        " median x = ", median_x,
        " IQR x = ", iqr_x)


#Calculate reversal rate
cutoff = mean_x - std_x
prev_rev_rate = Inf
tol = 0.1 # 
max_iters = 10

for n in 1:max_iters
    intervals, event_types, prop, mean_exc_x, std_exc_x, rev_rate = analyze_x_intervals(t, x, cutoff)
    println("rev rate: ", rev_rate, " per Myr")
    if abs(rev_rate - prev_rev_rate) < tol
        break
    end
    cutoff = mean_exc_x - std_exc_x
    prev_rev_rate = rev_rate
end
println("final rev rate: ", rev_rate, " per Myr")
println("proportion reversing: ", prop)

# plot time series 
idecimate = 1;
plot(t[1:idecimate:end],(x[1:idecimate:end]),
label="x",xlabel="time (Myr)",
ylabel="Dipole Moment  (1.0e22 A m2)"
)

# %%
#plot time series 
idecimate = 1;
plot(t[1:idecimate:end],(x[1:idecimate:end]),
    label="x",xlabel="time (Myr)",
    xlim=(0, 1),
    ylabel="Dipole Moment  (1.0e22 A m2)"
)

# %%
h = fit(Histogram,x,nbins=100)
plot(h,label="x(t)")

# %%
t_resampled, x_resampled = resample_linear(t, x, 0.01)

# %%
modelName= "model017"

# %%
filename = "$(modelName)/dipole_3000_resampled_Amax$(Amax)_Amin$(Amin)_R$(recurrence)_10kyr.txt"
println("Writing to: ", filename)
open(filename,"w")  do io
    writedlm(io,[t_resampled x_resampled])
end
g10 = x_resampled *1.0e22 *1.0e-7/(6371200.0^3)* 1.0e6 #returns values in microT
open(filename,"w")  do io
    writedlm(io,[t_resampled g10])
end

# %%
filename = "$(modelName)/parameters.txt"
println("Writing to: ", filename)
open(filename,"w")  do io
    println(io, modelName)
    println(io, "Amin = ", Amin, " Amax = " , Amax, " R = ", recurrence,  " mean x = ",mean_x," std x = ",std_x)
    println(io, "recurrence = ", recurrence, " Myr ",
        " mean x = ", mean_x,
        " std x = ", std_x,
        " median x = ", median_x,
        " IQR x = ", iqr_x)
    println(io, "final rev rate: ", rev_rate, " per Myr")
    println(io, "proportion reversing: ", prop)

end

# %%
using JSON3

data = (
    model = modelName,
    Amin = Amin,
    Amax = Amax,
    Recurrence = recurrence,
    mean_x = mean_x,
    std_x = std_x,
    median_x = median_x,
    iqr_x = iqr_x,
    rev_rate = rev_rate,
    prop_reversing = prop
)

json_string = JSON3.write(data; indent=4)  # pretty-print
write("$(modelName)/$(modelName)_metadata.json", json_string)

# %% [markdown]
# ## Combine with BB18

# %%
using CSV
using DataFrames

"""
Reads a tab-delimited text file with two columns:
First column becomes new header, second column becomes new first row.
"""
function read_tab_delimited_txt(file_path::String)
    df = CSV.File(file_path; delim='\t', header=false) |> DataFrame
    new_header = string.(df[:, 1])
    new_first_row = string.(df[:, 2])
    return new_header, new_first_row
end

"""
Combines the original CSV data with the new header and first row,
converting header units by multiplying by 1000.
"""
function combine_with_txt_header_and_row(
    csv_df::DataFrame, new_header::Vector{String},
    new_first_row::Vector{String}
)
    num_cols = size(csv_df, 2)
    new_header = new_header[1:num_cols]
    new_first_row = new_first_row[1:num_cols]

    # Convert numeric headers
    converted_header = String[]
    for col in new_header
        try
            converted = parse(Float64, col) * 1000
            push!(converted_header, string(Int(round(converted))))
        catch
            push!(converted_header, col)
        end
    end
    
    # Rename columns
    rename!(csv_df, Symbol.(converted_header))

    # Insert new first row
    new_first_row_vals = parse.(Float64, new_first_row[1:num_cols])
    cols = Symbol.(converted_header)
    new_row_df = DataFrame(reshape(new_first_row_vals, 1, :), cols)
    combined_df = vcat(new_row_df, csv_df)

    # Convert all columns to Float64 and multiply by 1000
    for col in names(combined_df)
        combined_df[!, col] .= Float64.(combined_df[!, col]) .* 1000
    end

    return  combined_df
end

# Run with specific models
bb18 = CSV.File(
    "C:/Users/murray98/Documents/Bruce Buffett model/code/bb18-v11/" *
    "bb18_v11/bb18_draws5.csv"; delim=' ', ignorerepeated=true,
    header=true
) |> DataFrame

times, g10 = read_tab_delimited_txt(
    "C:/Users/murray98/Documents/Bruce Buffett model/code/model026/" *
    "dipole_3000_resampled_Amax0.6_Amin-0.15_R0.006_10kyr.txt"
)

combined = combine_with_txt_header_and_row(bb18, times, g10)

CSV.write("model026/combined_output_julia.csv", combined)

# %%
combined

# %% [markdown]
# ## Loop

# %%
using Printf

# Path to your model directory
model_dir = "C://Users/murray98/Documents/Bruce Buffett model/code"

# Get all filenames in the directory
existing_files = readdir(model_dir)

# Filter names like "modelNNN"
model_nums = Int[]
for fname in existing_files
    m = match(r"model(\d{3})", fname)
    if m !== nothing
        push!(model_nums, parse(Int, m.captures[1]))
    end
end

# Determine the starting index for new models
start_index = isempty(model_nums) ? 1 : maximum(model_nums) + 1

# Generate Amin_list
#Amin_list = collect(0.4:0.04:0.6)
Amin_list = []
# Generate new model names
models = [@sprintf("model%03d", start_index + i - 1) for i in 1:length(Amin_list)]

# Example usage
for (modelName, Amin) in zip(models, Amin_list)
    println("Model: $modelName, Amin: $Amin")
end

# %%
Amin_list

# %%
models

# %%
Amin_list = -0.1:0.01:0.1
for (modelName, Amin) in zip(models, Amin_list)
    
    recurrence = 0.006
    nevents = 20000;
    tevent = rand(Exponential(recurrence),nevents);  # Poisson event times
    
    # plot distribution of event times
    println("mean recurrence time = ",mean(tevent)," Myr")
    histogram(tevent,label="event times",xlabel="event time (Myr)",ylabel="Number")
    
    
    Amax = 0.6
    #Amin = -1.5
    amp_p = rand(Uniform(Amin,Amax),nevents)
    
    # include random (white) noise
    np = rand(Normal(),2*nevents); #called wi in paper
    qp = 45;       #  gaussian noise variance
    
    # set level of quenching
    x0 = 5.0;
    
    # allocate memory for solution
    x = zeros(2*nevents);
    t = zeros(2*nevents);
    
    
    # decay rate for dipole (gamma = 1/tau)
    gamma = 0.025 * 1000;    # convert to Myr
    
    # initial condition
    t[1] = 0.0;
    x[1] = 5.0;
    j = 2;
    
    # integrate of number of events
    for i = j : nevents
        
        # magnetic diffusion over half time step dt
        dt = tevent[i]/2.0;
        t[j] = t[j-1] + dt;
        gp = exp(-x[j-1]^2/1.8^2);  # x-dependence of gaussian noise
        x[j] = x[j-1] * exp(-gamma * dt) + np[j]*sqrt(gp*qp*dt);;
        
        # magnetic diffusion over remaining time step
        j += 1;
        t[j] = t[j-1] + dt;
        x[j] = x[j-1] * exp(-gamma * dt)
        
        # evaluate quenching
        fp = 1.0/ (1.0 + (x[j]/x0)^2);
        gp = exp(-x[j]^2/1.8^2);
        
        # add event and random noise
        x[j] += amp_p[i] * x[j] * fp + np[j]*sqrt(gp*qp*dt); 
        j+= 1;
        
    end
    t[end] = t[end-1]
    x[end] = x[end-1]
    println("Amin = ", Amin, " Amax = " , Amax, " R = ", recurrence,  " mean x = ",mean_x," std x = ",std_x)
    mean_x = mean(abs.(x))
    std_x = std(abs.(x))
    median_x = median(abs.(x))
    iqr_x = quantile(abs.(x), 0.75) - quantile(abs.(x), 0.25)
    println("recurrence = ", recurrence, " Myr ",
            " mean x = ", mean_x,
            " std x = ", std_x,
            " median x = ", median_x,
            " IQR x = ", iqr_x)
    
    
    #Calculate reversal rate
    cutoff = mean_x - std_x
    prev_rev_rate = Inf
    tol = 0.1 # 
    max_iters = 10
    
    for n in 1:max_iters
        intervals, event_types, prop, mean_exc_x, std_exc_x, rev_rate = analyze_x_intervals(t, x, cutoff)
        println("rev rate: ", rev_rate, " per Myr")
        if abs(rev_rate - prev_rev_rate) < tol
            break
        end
        cutoff = mean_exc_x - std_exc_x
        prev_rev_rate = rev_rate
    end
    println("final rev rate: ", rev_rate, " per Myr")
    println("proportion reversing: ", prop)
    
    # plot time series 
    idecimate = 1;
    plot(t[1:idecimate:end],(x[1:idecimate:end]),
    label="x",xlabel="time (Myr)",
    ylabel="Dipole Moment  (1.0e22 A m2)"
    )
    
    t_resampled, x_resampled = resample_linear(t, x, 0.01)
    #Write to file
    if !isdir("$(modelName)")
        mkpath("$(modelName)")
    end
    filename = "$(modelName)/dipole_3000_resampled_Amax$(Amax)_Amin$(Amin)_R$(recurrence)_10kyr.txt"
    println("Writing to: ", filename)
    open(filename,"w")  do io
        writedlm(io,[t_resampled x_resampled])
    end
    g10 = x_resampled *1.0e22 *1.0e-7/(6371200.0^3)* 1.0e6 #converts from dipole moment to gauss coef, returns values in microT
    open(filename,"w")  do io
        writedlm(io,[t_resampled g10])
    end
    
    using JSON3

    data = (
        model = modelName,
        Amin = Amin,
        Amax = Amax,
        Recurrence = recurrence,
        mean_x = mean_x,
        std_x = std_x,
        median_x = median_x,
        iqr_x = iqr_x,
        rev_rate = rev_rate,
        prop_reversing = prop
    )
    
    json_string = JSON3.write(data; indent=4)  # pretty-print
    write("$(modelName)/$(modelName)_metadata.json", json_string)

    #Combine with BB18
    times, g10 = read_tab_delimited_txt(
        "C:/Users/murray98/Documents/Bruce Buffett model/code/$(modelName)/dipole_3000_resampled_Amax$(Amax)_Amin$(Amin)_R$(recurrence)_10kyr.txt"
    )
    
    combined = combine_with_txt_header_and_row(bb18, times, g10)
    
    CSV.write("$(modelName)/combined_output_julia.csv", combined)
    
end

# %%
combined
