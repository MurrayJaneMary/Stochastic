# %% [markdown]
# Trends in Dipole Field
# =====
# ***

# %% [markdown]
# Compute the trends in the dipole field from a realization of the stochastic model.

# %%
using Plots
using Distributions
using StatsBase
using DelimitedFiles
using Interpolations
using GLM

# %%
# Input realization of stochastic dynamo model
#
data = readdlm("dipole_3000.txt", '\t', Float64, '\n')
td = data[:,1];
xd = data[:,2];
ndata = length(td)
# Out:
# at row 0, column 0 : ArgumentError("number of rows in dims must be > 0, got 0")
#
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] dlm_fill(T::DataType, offarr::Vector{Vector{Int64}}, dims::Tuple{Int64, Int64}, has_header::Bool, sbuff::String, auto::Bool, eol::Char)
#     @ DelimitedFiles C:\Users\murray98\AppData\Local\Programs\Julia-1.8.1\share\julia\stdlib\v1.8\DelimitedFiles\src\DelimitedFiles.jl:515
#   [3] readdlm_string(sbuff::String, dlm::Char, T::Type, eol::Char, auto::Bool, optsd::Dict{Symbol, Union{Char, Integer, Tuple{Integer, Integer}}})
#     @ DelimitedFiles C:\Users\murray98\AppData\Local\Programs\Julia-1.8.1\share\julia\stdlib\v1.8\DelimitedFiles\src\DelimitedFiles.jl:471
#   [4] readdlm_auto(input::String, dlm::Char, T::Type, eol::Char, auto::Bool; opts::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ DelimitedFiles C:\Users\murray98\AppData\Local\Programs\Julia-1.8.1\share\julia\stdlib\v1.8\DelimitedFiles\src\DelimitedFiles.jl:247
#   [5] readdlm_auto
#     @ C:\Users\murray98\AppData\Local\Programs\Julia-1.8.1\share\julia\stdlib\v1.8\DelimitedFiles\src\DelimitedFiles.jl:233 [inlined]
#   [6] #readdlm#6
#     @ C:\Users\murray98\AppData\Local\Programs\Julia-1.8.1\share\julia\stdlib\v1.8\DelimitedFiles\src\DelimitedFiles.jl:226 [inlined]
#   [7] readdlm(input::String, dlm::Char, T::Type, eol::Char)
#     @ DelimitedFiles C:\Users\murray98\AppData\Local\Programs\Julia-1.8.1\share\julia\stdlib\v1.8\DelimitedFiles\src\DelimitedFiles.jl:226
#   [8] top-level scope
#     @ In[4]:3
#   [9] eval
#     @ .\boot.jl:368 [inlined]
#  [10] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base .\loading.jl:1428

# %%
idecimate = 100;
plot(td[1:idecimate:end],xd[1:idecimate:end],
    xlabel="time (magnetic diffusion time)",
    ylabel="dipole moment",label="x")

# %%
# Interpolate onto a uniform time grid
dt =  0.001; # 1 kyr interval
tinp = (0.0 : dt : td[end]);
nodes = (td,);
itp = interpolate(nodes,xd,Gridded(Linear()));
xinp = itp(tinp);
ndata = length(tinp)
println(ndata)
plot(tinp[1:idecimate:end],xinp[1:idecimate:end],
    xlabel="time",
    ylabel="dipole moment",
    label="x")
# Out:
# Excessive output truncated after 3897061 bytes.

# %%
# take absolute value of realization
a = abs.(xinp);
xbar = mean(a);
xmed = median(a)
println("mean = ",xbar,"  ","median = ",xmed," skewness = ",skewness(a))
# Out:
# mean = 4.811603281787792  median = 4.775387981734687 skewness = 0.06837779825533073

# %% [markdown]
# Compute correlation coefficient of amplitude $a(t) = |x(t)|$.

# %%
# compute correlation of a(t)
nlags = 100;
lag = zeros(nlags)
c = zeros(nlags)
c[1] = 1.0;
da = a .- mean(a);
for i = 2 : nlags
    lag[i] = (i-1) * dt;
    y = da[i:end];
    z = da[1:end-i+1];
    c[i] = cor(da[1:end-i+1],da[i:end]);
end
plot(lag*1000,c,title="Correlation",
    xlabel="Time Lag [kyr]",
    ylabel="correlation",
    label="realization",
    xlim=(0,100),
    ylim=(0,1.0))

# %% [markdown]
# Compute least-squares fit using GLM package

# %%
function slopes(nintvl,t,x)
    nsamples = Int(floor(length(x)/nintvl));
    b = zeros(nsamples)
    X = ones(nintvl,2)
    X[:,2] = t[1:nintvl] .- t[1];
    
    for i = 1 : nsamples
        istart = 1 + (i-1) * nintvl;
        ols = lm(X,x[istart:istart+nintvl-1]);
        b[i] = coef(ols)[2];
    end
    
return b
end
# Out:
# slopes (generic function with 1 method)

# %% [markdown]
# Compute skewness for time intervals between 2kyr to 50 kyr (every 2 kyr)

# %%
sk = zeros(25);
err = zeros(25);
window = zeros(25);
kyr = 1000.0;    # conversion from million years

for i = 1 : 25
    b = slopes(i * 2,tinp,a);
    sk[i] = skewness(b);
    err[i] = sqrt(6.0/length(b));
    window[i] = i * 2.0 * dt;
end

plot(window*kyr,sk,yerror=err,
    xlabel="Time Window [kyr]", 
    ylabel="Skewness",
    st=:scatter,
    ylim=(-0.1,1.0),
    legend=nothing)

# %%
savefig("skewness.pdf")
# Out:
# syntax: incomplete: premature end of input
#
# Stacktrace:
#  [1] top-level scope
#    @ In[10]:1
#  [2] eval
#    @ .\boot.jl:368 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1428
