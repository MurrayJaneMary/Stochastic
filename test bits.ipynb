# %%
for a in range(0,10):
    for b in range(0,5):
        print("a1", a)
        print("b", b)
    print("a2", a)
    print("b", b)
print("a3", a)
print("b", b)
# Out:
# a1 0
# b 0
# a1 0
# b 1
# a1 0
# b 2
# a1 0
# b 3
# a1 0
# b 4
# a2 0
# b 4
# a1 1
# b 0
# a1 1
# b 1
# a1 1
# b 2
# a1 1
# b 3
# a1 1
# b 4
# a2 1
# b 4
# a1 2
# b 0
# a1 2
# b 1
# a1 2
# b 2
# a1 2
# b 3
# a1 2
# b 4
# a2 2
# b 4
# a1 3
# b 0
# a1 3
# b 1
# a1 3
# b 2
# a1 3
# b 3
# a1 3
# b 4
# a2 3
# b 4
# a1 4
# b 0
# a1 4
# b 1
# a1 4
# b 2
# a1 4
# b 3
# a1 4
# b 4
# a2 4
# b 4
# a1 5
# b 0
# a1 5
# b 1
# a1 5
# b 2
# a1 5
# b 3
# a1 5
# b 4
# a2 5
# b 4
# a1 6
# b 0
# a1 6
# b 1
# a1 6
# b 2
# a1 6
# b 3
# a1 6
# b 4
# a2 6
# b 4
# a1 7
# b 0
# a1 7
# b 1
# a1 7
# b 2
# a1 7
# b 3
# a1 7
# b 4
# a2 7
# b 4
# a1 8
# b 0
# a1 8
# b 1
# a1 8
# b 2
# a1 8
# b 3
# a1 8
# b 4
# a2 8
# b 4
# a1 9
# b 0
# a1 9
# b 1
# a1 9
# b 2
# a1 9
# b 3
# a1 9
# b 4
# a2 9
# b 4
# a3 9
# b 4
